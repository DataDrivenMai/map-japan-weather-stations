# %% [raw]
# ---
# title: "Japan Meteorological Agency (JMA) Automated Meteorological Data Acquisition System (AMeDAS) Map"
# author: Mai Tanaka
# date: 2026-06-26
# abstract: "Map of the JMA stations collecting meteorological data in Japan."
# image-alt: "Map of the Japan Meteorological Agency (JMA) Automated Meteorological Data Acquisition System (AMeDAS) stations"
# categories:
#   - (A) Data Collection
#   - (B) Data Preprocessing
#   - (D) Data Visualization
#   - weather data
#   - Japan Meteorological Agency
#   - data scraping
#   - data parsing
#   - library - requests
#   - library - bs4
#   - library - datetime
#   - library - pytz
#   - library - pandas
# lightbox: true
# bibliography: "../../references.bib"
# csl: "../../nature.csl"
# other-links:
#   - text: JMA website
#     href: https://www.jma.go.jp/jma/index.html
#     icon: cloud-sun
# code-links:
#   - text: View Code
#     href: https://github.com/DataDrivenMai/DataDrivenMai-blog/tree/main/jma-weather-scraping
#     icon: github
# filters:
#   - social-share
# share:
#     permalink: "https://www.datadrivenmai.com/projects/jma-station-map/deets-n-docs.html"
#     location: "before-body"
#     linkedin: true
#     twitter: true
#     facebook: true
#     mastodon: true
#     bsky: true
# ---

# %%
# A map of all 1316 Japan Meteorological Agency (JMA) weather stations to help data scrapers. Visually locate a weather station of your choice on either map, and it will provide you with the `'prec_no'`, `'block_no'` and whether it is a `'s'` type of an `'a'` type station. With this information, you can quickly identify the URL needed when web scraping meteorological data from this weather station.

# The map below displays all Automated Meteorological Data Acquisition System (AMeDAS) weather stations in Japan, and is color-coded according to its jurisdiction. The map on the right shows the JMA weather stations for each jurisdiction. Pop-ups on the right map also give detailed information on:

# - Location and elevation of the weather station
# - Which meteorological data are collected at the site
# - When the data collection begun

# %%
# Download dataframe table from csv

# Text for top left
